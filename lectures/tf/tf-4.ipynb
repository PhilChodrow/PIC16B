# %% [markdown]
# # Mixed Data Features
#
# In previous lectures, we've used neural networks to perform "basic" classification, image classification, and text classification. In each of these, we used a single pipeline that we custom built for the data we needed to work with, usually enclosed within a `keras.models.Sequential()` model. This worked fine for those situations, but what happens when we have *multiple* complex data components that we would like to use in our models? For example, maybe we would like to do classification in a dataset containing both:
#
# 1. Pictures (images) and captions (text).
# 2. Descriptions (text) and timestamps (numbers).
# 3. Article bodies (text) and titles (different text).
#
# Of course, it's possible to come up with various ad hoc ways to smoosh pieces of data together, but this isn't usually the right approach. A better thing to do is to create a more flexible model that accepts and appropriately processes different kinds of inputs. In this lecture, we'll learn how to do this.
#
# ### Key Tools
#
# - Labeled data sets.
# - The Keras functional API (alternative to Sequential API).

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import re
import string

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow import keras

# requires update to tensorflow 2.4
# >>> conda activate PIC16B
# >>> pip install tensorflow==2.4
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from tensorflow.keras.layers.experimental.preprocessing import StringLookup

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# for embedding viz
import plotly.express as px 
import plotly.io as pio
pio.templates.default = "plotly_white"

# %% [markdown]
# Our data set for this lecture contains various information about various musical tracks produced between the years 1950 and 2019. You can find it on Kaggle [here](https://www.kaggle.com/saurabhshahane/music-dataset-1950-to-2019). The data was originally published in the following data publication:
#
# > Moura, Luan; Fontelles, Emanuel; Sampaio, Vinicius; França, Mardônio (2020), “Music Dataset: Lyrics and Metadata from 1950 to 2019”, Mendeley Data, V3, doi: 10.17632/3t9vbwxgr5.3

# %%
url = "https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/tcc_ceds_music.csv"
df = pd.read_csv(url)

# %% [markdown]
# Let's take a quick look:

# %%
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
#    world/life  ...   sadness  feelings  danceability  loudness  acousticness  \
# 0    0.000598  ...  0.380299  0.117175      0.357739  0.454119      0.997992
# 1    0.443435  ...  0.001284  0.001284      0.331745  0.647540      0.954819
# 2    0.002770  ...  0.002770  0.225422      0.456298  0.585288      0.840361
# 3    0.001548  ...  0.225889  0.001548      0.686992  0.744404      0.083935
# 4    0.417772  ...  0.068800  0.001350      0.291671  0.646489      0.975904
#
#    instrumentalness   valence    energy       topic  age
# 0          0.901822  0.339448  0.137110     sadness  1.0
# 1          0.000002  0.325021  0.263240  world/life  1.0
# 2          0.000000  0.351814  0.139112       music  1.0
# 3          0.199393  0.775350  0.743736    romantic  1.0
# 4          0.000246  0.597073  0.394375    romantic  1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# We have a number of columns here! We'll focus on a few subsets in particular:
#
# The `genre` describes the overall genre of the track. It has seven values:

# %%
df.groupby("genre").size()
# Out:
# genre
# blues      4604
# country    5445
# hip hop     904
# jazz       3845
# pop        7042
# reggae     2498
# rock       4034
# dtype: int64

# %% [markdown]
# There data also includes
# - The complete `lyrics` of the track (if it has any)
# - The normalized `age` of the track (1.0 corresponds to tracks released in 1950, 0.0 corresponds to more recent tracks)
# - A selection of columns that give the track numerical scores reflecting various attributes and topics, such as "danceability," "loudness," and "acousticness."
#
# There are also other columns in the data, but these are the ones we're going to focus on for this analysis. We are going to subset things a bit: let's focus on only a few genres, and on only relatively recent tracks.

# %%
df = df[df["release_date"] > 2000]
genres = ["blues", "hip hop", "country"]
df = df[df["genre"].apply(lambda x: x in genres)]

# %% [markdown]
# Next, let's do a categorical encoding of the `genre` column.

# %%
le = LabelEncoder()
df["genre"] = le.fit_transform(df["genre"])
num_genres = len(df["genre"].unique())

# %% [markdown]
# ## Create a Dataset
#
# We're now ready to create a TensorFlow `Dataset`. This is going to be a little more involved than last time, because we need to distinguish between different kinds of model inputs.
#
# Here's a list of all the scalar "score" columns in the data frame.

# %%
scalars = ['dating', 
           'violence', 
           'world/life', 
           'night/time',
           'shake the audience',
           'family/gospel', 
           'romantic', 
           'communication',
           'obscene', 
           'music', 
           'movement/places', 
           'light/visual perceptions',
           'family/spiritual', 
           'like/girls', 
           'sadness', 
           'feelings', 
           'danceability',
           'loudness', 
           'acousticness', 
           'instrumentalness', 
           'valence', 
           'energy']

# %% [markdown]
# Because we have multiple inputs, we are going to construct our `Dataset` from a tuple of dictionaries. The first dictionary is going to specify the different components in the predictor data, while the second dictionary is going to specify the different components of the target data.

# %%
data = tf.data.Dataset.from_tensor_slices(
    (
        {
            "lyrics" : df[["lyrics"]], 
            "scalars" : np.array(df[scalars])}, 
        {
            "genre" : df[["genre"]]
        }
    )
)

# %% [markdown]
# Next, we are going to perform a train/test/validation split. For each of the three split `Datasets`, we are going to *batch* them into small chunks of data. This helps with training runtime later.

# %%
data = data.shuffle(buffer_size = len(data))

train_size = int(0.7*len(data))
val_size   = int(0.1*len(data))

train = data.take(train_size).batch(20)
val   = data.skip(train_size).take(val_size).batch(20)
test  = data.skip(train_size + val_size).batch(20)

len(train), len(val), len(test)
# Out:
# (134, 19, 39)

# %% [markdown]
# Each of the numbers above should be multipled by the batch size to give the total number of rows in each `Dataset`.
#
# The code below sets up exactly the same text preprocessing that we did [last lecture](https://nbviewer.jupyter.org/github/PhilChodrow/PIC16B/blob/master/lectures/tf/tf-3.ipynb).

# %%
size_vocabulary = 2000

def standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    no_punctuation = tf.strings.regex_replace(lowercase,
                                  '[%s]' % re.escape(string.punctuation),'')
    return no_punctuation 

vectorize_layer = TextVectorization(
    standardize=standardization,
    max_tokens=size_vocabulary, # only consider this many words
    output_mode='int',
    output_sequence_length=500) 

vectorize_layer.adapt(np.array(df_train["lyrics"]))

# %% [markdown]
# ## The Keras Functional API
#
# In previousl lectures, we used the `Sequential` API for constructing models. For example, we wrote code like this:
#
# ```python
# model = tf.keras.Sequential([
#   layers.Embedding(max_tokens, output_dim = 3),
#   layers.Dropout(0.2),
#   layers.GlobalAveragePooling1D(),
#   layers.Dropout(0.2),
#   layers.Dense(len(categories))]
# )
# ```
#
# This model is designed to accept a single kind of input (in this case text) and spit out a single output. However, in our case we have two distinct *kinds* of input: the song lyrics and the scalar scores. It wouldn't really make much sense to pass the scalar scores through a text vectorization or embedding layer. For this reason, we need to move beyond the `Sequential` API and instead constructing our models using a somewhat more manual approach, referred to as the `Functional` API.

# %% [markdown]
# ### Inputs
#
# Start by specifying the two kinds of `keras.Input` for our model. You should have one input for each qualitatively distinct "kind" of predictor data. All the parameters here are important:
#
# - `shape` should describe the shape of a single item of data. For example, the `lyrics` column contains just one entry for each song, so the shape is `(1,)` (a tuple of length 1). On the other hand, there are `len(scalars) = 22` distinct columns of scalar scores.
# - the `name` should be some descriptive name that you're able to remember for later.
# - The `dtype` specifies the kind of data contained in each of the input tensors.

# %%
# inputs

lyrics_input = keras.Input(
    shape = (1,), 
    name = "lyrics",
    dtype = "string"
)

scalars_input = keras.Input(
    shape = (len(scalars),), 
    name = "scalars",
    dtype = "float64"
)

# %% [markdown]
# ## Hidden Layers
#
# First, let's write a pipeline for the lyrics. This pipeline is pretty much the same as the one we used earlier for text classification -- we're just building it differently.

# %%
# layers for processing the lyrics, pretty much the same as from our lecture
# on text classification
lyrics_features = vectorize_layer(lyrics_input)
lyrics_features = layers.Embedding(size_vocabulary, 3, name = "embedding")(lyrics_features)
lyrics_features = layers.Dropout(0.2)(lyrics_features)
lyrics_features = layers.GlobalAveragePooling1D()(lyrics_features)
lyrics_features = layers.Dropout(0.2)(lyrics_features)
lyrics_features = layers.Dense(32)(lyrics_features)

# %% [markdown]
# Next, let's write a pipeline for the scalars. We don't need to do anything fancy with them, so instead of messing with `Embeddings` and the like, we're just going to pass them through a `Dense` layer.

# %%
scalar_features = layers.Dense(32)(scalars_input)

# %% [markdown]
# Here's simultaneously the most important and most boring part of the whole model: we are going to `concatenate` the output of the `lyrics` pipeline with the output of the `scalar` pipeline:

# %%
main = layers.concatenate([lyrics_features, scalar_features], axis = 1)

# %% [markdown]
# Finally, let's pass the consolidated set of computed features through a few more `Dense` layers. Remember that the very last `Dense` layer should have a number of outputs equal to the number of classes in the data.
#
# **Observe that the output layer has a name, and that this name matches the key corresponding to the target data in the `Datasets` we will pass to the model.** This is how TensorFlow knows which part of our data set to compare against the outputs!

# %%
main = layers.Dense(32)(main)
output = layers.Dense(num_genres, name = "genre")(main)

# %% [markdown]
# So far, we haven't actually created a model yet -- just a bunch of interrelated layers. We create the model by specifying the input(s) and output.

# %%
model = keras.Model(
    inputs = [lyrics_input, scalars_input],
    outputs = output
)

# %% [markdown]
# The model summary provides one good way to look at the structure of the model, but it can be difficult to read when there are multiple inputs:

# %%
model.summary()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# lyrics (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# text_vectorization_12 (TextVect (None, 500)          0           lyrics[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 500, 3)       6000        text_vectorization_12[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 500, 3)       0           embedding[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_15 (Gl (None, 3)            0           dropout_30[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 3)            0           global_average_pooling1d_15[0][0]
# __________________________________________________________________________________________________
# scalars (InputLayer)            [(None, 22)]         0
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 32)           128         dropout_31[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 32)           736         scalars[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64)           0           dense_30[0][0]
#                                                                  dense_31[0][0]
# __________________________________________________________________________________________________
# hidden_1 (Dense)                (None, 32)           2080        concatenate_15[0][0]
# __________________________________________________________________________________________________
# genre (Dense)                   (None, 3)            99          hidden_1[0][0]
# ==================================================================================================
# Total params: 9,043
# Trainable params: 9,043
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Something a bit more visually attractive can be obtained by using the `plot_model` function:

# %%
keras.utils.plot_model(model)

# %% [markdown]
# Now we're ready to train and evaluate our model as usual! As always, we need to compile:

# %%
model.compile(optimizer = "adam",
              loss = losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy']
)

# %% [markdown]
# And now we train!

# %%
history = model.fit(train, 
                    validation_data=val,
                    epochs = 50)
# Out:
# Epoch 1/50
# 134/134 [==============================] - 1s 6ms/step - loss: 1.0280 - accuracy: 0.4577 - val_loss: 0.8050 - val_accuracy: 0.6500
# Epoch 2/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.8000 - accuracy: 0.6211 - val_loss: 0.7669 - val_accuracy: 0.6421
# Epoch 3/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.7257 - accuracy: 0.6735 - val_loss: 0.7177 - val_accuracy: 0.6711
# Epoch 4/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.7147 - accuracy: 0.6676 - val_loss: 0.7233 - val_accuracy: 0.7026
# Epoch 5/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.6898 - accuracy: 0.6784 - val_loss: 0.6247 - val_accuracy: 0.6974
# Epoch 6/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.6584 - accuracy: 0.7099 - val_loss: 0.6256 - val_accuracy: 0.7474
# Epoch 7/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.6302 - accuracy: 0.7229 - val_loss: 0.5881 - val_accuracy: 0.7605
# Epoch 8/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.5707 - accuracy: 0.7617 - val_loss: 0.5678 - val_accuracy: 0.7737
# Epoch 9/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.5578 - accuracy: 0.7530 - val_loss: 0.5570 - val_accuracy: 0.7474
# Epoch 10/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.5486 - accuracy: 0.7605 - val_loss: 0.5269 - val_accuracy: 0.7553
# Epoch 11/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.5527 - accuracy: 0.7498 - val_loss: 0.4568 - val_accuracy: 0.8026
# Epoch 12/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.5125 - accuracy: 0.7756 - val_loss: 0.4671 - val_accuracy: 0.8158
# Epoch 13/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.5075 - accuracy: 0.7809 - val_loss: 0.4350 - val_accuracy: 0.8368
# Epoch 14/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4657 - accuracy: 0.8079 - val_loss: 0.4361 - val_accuracy: 0.8105
# Epoch 15/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4517 - accuracy: 0.8038 - val_loss: 0.3653 - val_accuracy: 0.8421
# Epoch 16/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4385 - accuracy: 0.8112 - val_loss: 0.4853 - val_accuracy: 0.7921
# Epoch 17/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4430 - accuracy: 0.8064 - val_loss: 0.3588 - val_accuracy: 0.8684
# Epoch 18/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4067 - accuracy: 0.8394 - val_loss: 0.3525 - val_accuracy: 0.8553
# Epoch 19/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3950 - accuracy: 0.8396 - val_loss: 0.3222 - val_accuracy: 0.8816
# Epoch 20/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.4069 - accuracy: 0.8331 - val_loss: 0.3517 - val_accuracy: 0.8579
# Epoch 21/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3938 - accuracy: 0.8279 - val_loss: 0.3462 - val_accuracy: 0.8553
# Epoch 22/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3480 - accuracy: 0.8543 - val_loss: 0.3076 - val_accuracy: 0.8789
# Epoch 23/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3691 - accuracy: 0.8410 - val_loss: 0.3170 - val_accuracy: 0.8711
# Epoch 24/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3656 - accuracy: 0.8411 - val_loss: 0.3163 - val_accuracy: 0.8816
# Epoch 25/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3153 - accuracy: 0.8652 - val_loss: 0.2236 - val_accuracy: 0.9368
# Epoch 26/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3397 - accuracy: 0.8619 - val_loss: 0.2179 - val_accuracy: 0.9237
# Epoch 27/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3296 - accuracy: 0.8694 - val_loss: 0.2836 - val_accuracy: 0.8895
# Epoch 28/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3012 - accuracy: 0.8771 - val_loss: 0.2676 - val_accuracy: 0.9105
# Epoch 29/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3359 - accuracy: 0.8592 - val_loss: 0.2616 - val_accuracy: 0.8816
# Epoch 30/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2938 - accuracy: 0.8819 - val_loss: 0.2390 - val_accuracy: 0.9026
# Epoch 31/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3270 - accuracy: 0.8684 - val_loss: 0.2705 - val_accuracy: 0.8921
# Epoch 32/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2933 - accuracy: 0.8710 - val_loss: 0.2392 - val_accuracy: 0.9158
# Epoch 33/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2987 - accuracy: 0.8786 - val_loss: 0.2187 - val_accuracy: 0.9132
# Epoch 34/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3086 - accuracy: 0.8667 - val_loss: 0.2096 - val_accuracy: 0.9211
# Epoch 35/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3034 - accuracy: 0.8743 - val_loss: 0.2103 - val_accuracy: 0.9211
# Epoch 36/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2713 - accuracy: 0.8895 - val_loss: 0.2198 - val_accuracy: 0.9053
# Epoch 37/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.3165 - accuracy: 0.8664 - val_loss: 0.2324 - val_accuracy: 0.9184
# Epoch 38/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2754 - accuracy: 0.8883 - val_loss: 0.2085 - val_accuracy: 0.9237
# Epoch 39/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2584 - accuracy: 0.8888 - val_loss: 0.1900 - val_accuracy: 0.9289
# Epoch 40/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2809 - accuracy: 0.8852 - val_loss: 0.2018 - val_accuracy: 0.9289
# Epoch 41/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2594 - accuracy: 0.8891 - val_loss: 0.2526 - val_accuracy: 0.9000
# Epoch 42/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2677 - accuracy: 0.8881 - val_loss: 0.1959 - val_accuracy: 0.9053
# Epoch 43/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2768 - accuracy: 0.8828 - val_loss: 0.1946 - val_accuracy: 0.9237
# Epoch 44/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2527 - accuracy: 0.9113 - val_loss: 0.1913 - val_accuracy: 0.9342
# Epoch 45/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2512 - accuracy: 0.8924 - val_loss: 0.1674 - val_accuracy: 0.9289
# Epoch 46/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2851 - accuracy: 0.8784 - val_loss: 0.2212 - val_accuracy: 0.9026
# Epoch 47/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2690 - accuracy: 0.8867 - val_loss: 0.2038 - val_accuracy: 0.9342
# Epoch 48/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2510 - accuracy: 0.8986 - val_loss: 0.1563 - val_accuracy: 0.9421
# Epoch 49/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2673 - accuracy: 0.8856 - val_loss: 0.1823 - val_accuracy: 0.9421
# Epoch 50/50
# 134/134 [==============================] - 1s 5ms/step - loss: 0.2785 - accuracy: 0.8831 - val_loss: 0.1661 - val_accuracy: 0.9395

# %%
from matplotlib import pyplot as plt
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])

# %% [markdown]
# ## Visualizing Embeddings
#
# As usual, it's fun to take a look at the embedding learned by our model. Provided that we gave our embedding layer a name, the same approach as last time works just fine:

# %%
weights = model.get_layer('embedding').get_weights()[0] # get the weights from the embedding layer
vocab = vectorize_layer.get_vocabulary()                # get the vocabulary from our data prep for later

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
weights = pca.fit_transform(weights)

embedding_df = pd.DataFrame({
    'word' : vocab, 
    'x0'   : weights[:,0],
    'x1'   : weights[:,1]
})

# %%
import plotly.express as px 
fig = px.scatter(embedding_df, 
                 x = "x0", 
                 y = "x1", 
                 size = list(np.ones(len(embedding_df))),
                 size_max = 2,
                 hover_name = "word")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="488c025b-bf9c-498f-b08c-03925cb8147d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("488c025b-bf9c-498f-b08c-03925cb8147d")) {
#                     Plotly.newPlot(
#                         '488c025b-bf9c-498f-b08c-03925cb8147d',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>x0=%{x}<br>x1=%{y}<br>size=%{marker.size}", "hovertext": ["", "[UNK]", "know", "like", "time", "come", "yeah", "go", "cause", "feel", "away", "life", "leave", "right", "want", "baby", "tell", "heart", "gonna", "think", "long", "live", "good", "break", "look", "night", "need", "wanna", "hand", "world", "mind", "hold", "hear", "fuck", "say", "black", "little", "home", "better", "bitch", "turn", "head", "girl", "shit", "fall", "nigga", "walk", "lose", "change", "play", "stay", "sing", "eye", "take", "thing", "song", "dream", "gotta", "hard", "money", "stand", "things", "start", "blue", "real", "bout", "niggas", "hell", "believe", "stop", "face", "get", "light", "people", "tear", "try", "watch", "drink", "wrong", "kill", "line", "fight", "bring", "lord", "word", "place", "talk", "tonight", "party", "lyric", "days", "soul", "sound", "damn", "cold", "high", "work", "sleep", "burn", "roll", "pain", "hurt", "commercial", "game", "call", "miss", "wish", "nothin", "blood", "mean", "learn", "lonely", "inside", "shoot", "give", "kiss", "remember", "make", "road", "grind", "beat", "forget", "sweet", "open", "dead", "smoke", "devil", "gettin", "true", "see", "everybody", "fool", "love", "somebody", "throw", "truth", "best", "body", "till", "grow", "goin", "drop", "write", "matter", "listen", "care", "ride", "ready", "free", "breathe", "save", "maybe", "tryin", "touch", "years", "door", "blow", "white", "help", "close", "ring", "young", "livin", "deep", "rain", "shake", "guess", "die", "keep", "blame", "pull", "today", "morning", "catch", "crazy", "dance", "hide", "alive", "death", "stick", "wall", "wait", "friends", "run", "sure", "strong", "comin", "straight", "talkin", "woman", "reason", "past", "lie", "step", "late", "pass", "lookin", "kick", "round", "girls", "feet", "wind", "somethin", "sell", "hole", "drive", "scar", "check", "fade", "smile", "shine", "fear", "cry", "understand", "bone", "thank", "stone", "water", "hang", "rest", "pick", "kind", "apart", "goodbye", "couldn", "mama", "piece", "house", "arm", "whoa", "forever", "wonder", "spend", "hate", "dark", "build", "follow", "tire", "heaven", "music", "country", "blind", "street", "evil", "pray", "easy", "alright", "tomorrow", "mouth", "lead", "cross", "tight", "slow", "fast", "reach", "wear", "promise", "rhyme", "voice", "streets", "speak", "doin", "finally", "floor", "city", "raise", "land", "begin", "fine", "tryna", "boys", "outta", "heavy", "fuckin", "room", "feelin", "train", "teach", "friend", "brain", "drinkin", "flow", "wouldn", "bust", "track", "dope", "picture", "knock", "finger", "breath", "gold", "felt", "block", "bear", "summer", "steal", "pretty", "okay", "kid", "songs", "skin", "lips", "point", "moon", "river", "half", "simple", "shut", "plan", "ghost", "cool", "babe", "worry", "waste", "tree", "runnin", "trust", "sayin", "memory", "clear", "chain", "read", "green", "star", "slip", "sign", "radio", "push", "end", "brother", "wasn", "rise", "move", "knees", "soon", "lock", "south", "happen", "beautiful", "holy", "waitin", "sick", "niggaz", "dirty", "deal", "couple", "style", "power", "band", "send", "scream", "record", "dust", "different", "second", "memories", "booty", "phone", "nights", "flame", "darling", "control", "choose", "school", "number", "meet", "dear", "wild", "truck", "taste", "outside", "hearts", "warm", "spot", "show", "tongue", "bind", "afraid", "million", "middle", "pay", "mother", "hood", "fever", "cash", "thousand", "swear", "shame", "hoe", "doubt", "belong", "whiskey", "peace", "loud", "ways", "shoe", "share", "repeat", "club", "walkin", "trouble", "thinkin", "moment", "woah", "bottle", "bleed", "search", "glass", "window", "sittin", "makin", "let", "lay", "hair", "weed", "momma", "minute", "longer", "daddy", "yesterday", "dress", "child", "pride", "nice", "mistake", "guitar", "wide", "rule", "fail", "clock", "remain", "pour", "oooh", "luck", "l ...
